# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[10,15,13,18,16]
y1=[24,16,9,4,1]

plt.plot(x,y)
plt.plot(x,y1)
plt.title("BAsic Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()
